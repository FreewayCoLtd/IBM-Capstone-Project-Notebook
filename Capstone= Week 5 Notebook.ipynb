# %% [markdown]
# # Capstone Project - A Comparative Analysis of Venue Interest in Kobe City and Osaka City Japan Using Foursquare API Data
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# The main objective of this study is to understand key venue categories and the top 25 venues within each category that remain popular despite the state of emergency declarations and restrictions placed on restaurants, shops, and other places of interest around the following major train stations
# -	Umeda Station, Osaka
# -	Sannomiya Station, Kobe
#
# The author rationalizes that such a study could be of interest to the following key stakeholder groups in terms of making key strategic decisions
# The City Hall which could leverage the data to identify potential areas of risk for the spread of infections during peak times where there is frequent movement of large groups of people or until a satisfactory target demographic has been vaccinated.
# Business owners and individuals seeking to relocate their offices or set up a new business in terms of identifying a shift of key areas of commercial activity
# Real-estate and construction companies to consider land value, demand, and the repurposing of existing buildings.
# Business owners and entrepreneurs in terms of understanding which types of venues are popular to consider investing in or setting up new ventures.

# %% [markdown]
# ## Data Sources and Methodology  <a name="Data Sources and Methodology"></a>

# %% [markdown]
# In order to determine the key venue categories between each major city, the first stage will involve using data from Foursquare's API will be used to understand venues and their popularity within a 1000 meter (1km) radius from each station based on the following conditions
# - 25 most popular venue categories
# - 25 most popular venues within each category
#
# The second stage of this process would be to compare and contrast the results of the two cities which will involve A machine learning based comparison of data using K-means clustering with the same results from stage 1 to generate the 10 most popular venues
#
# The final stage of the data analysis process would involve testing the k-means clustering model with a larger set of data by increasing following variables for the same two cities.
# - most popular venue categories
# - most popular venue within each category
# - a 2000 meter (2km) radius from each station for each venue

# %% [markdown]
# ### Library Import List  <a name="Library Import List"></a>

# %%
#Add list of libraries here
import requests
# !pip install folium
import folium
import pandas as pd
import numpy as np
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
! pip install folium==0.5.0
import folium # plotting library
import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 
from sklearn.cluster import KMeans 
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
import matplotlib.cm as cm
import matplotlib.colors as colors
print('Libraries imported.')
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium) (2.25.1)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium) (0.4.2)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium) (1.15.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jinja2->folium) (2.0.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium) (1.26.6)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: folium==0.5.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium==0.5.0) (2.25.1)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from folium==0.5.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jinja2->folium==0.5.0) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium==0.5.0) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium==0.5.0) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from requests->folium==0.5.0) (2.8)
# Libraries imported.

# %% [markdown]
# ### Foursquare API Configuration <a name="Foursquare API Configuration"></a>

# %%
CLIENT_ID = 'HDAKBGBGZTCF3FFZQXSF2YJGLUMKUG42ZIIOCCONKXDTDIXC'
CLIENT_SECRET = 'ZDSQ1LXYADSTCIM45TJXJTRLHKE0FFR41X2RMXCIDJWGKYKS'
VERSION = '20180604'
LIMIT = 30
print('Foursquare API credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Foursquare API credentails:
# CLIENT_ID: HDAKBGBGZTCF3FFZQXSF2YJGLUMKUG42ZIIOCCONKXDTDIXC
# CLIENT_SECRET:ZDSQ1LXYADSTCIM45TJXJTRLHKE0FFR41X2RMXCIDJWGKYKS

# %% [markdown]
# ### Stage 1 - Initial Data Extraction <a name="Stage 1 - Initial Data Extraction"></a>

# %%
# Find identify top 10 popular venue categories and subsequent top 10 venues around the following train stations within a 1,000m radius 
# - Umeda Station, Osaka, Japan
# - Sannomiya Station, Kobe, Japan

# Use coordinates of each station as a point

# %% [markdown]
# #### Umeda Station, Osaka, Japan Analysis <a name="Umeda Station, Osaka, Japan Analysis "></a>

# %%
## Get Coordinates of Umeda Station, Osaka, Japan

osaka_address = 'Umeda Station, Osaka, Japan'

geolocator = Nominatim(user_agent="foursquare_agent")
osaka_location = geolocator.geocode(osaka_address)
osaka_latitude = osaka_location.latitude
osaka_longitude = osaka_location.longitude
print('The latitude and longitude for Umeda Station is:', osaka_latitude, osaka_longitude)
# Out:
# The latitude and longitude for Umeda Station is: 34.7053631 135.4979778

# %%
# Identify top 10 popular venue categories and subsequent top 10 venues around Umeda Station, Osaka, Japan
osaka_latitude = osaka_location.latitude
osaka_longitude= osaka_location.longitude
radius = 1000
LIMIT = 25
osaka_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, osaka_latitude, osaka_longitude, VERSION, radius, LIMIT)
osaka_url

osaka_results = requests.get(osaka_url).json()
'There are {} around Sannomiya Station, Kobe, Japan.'.format(len(osaka_results['response']['groups'][0]['items']))

osaka_items = osaka_results['response']['groups'][0]['items']
osaka_items[0]

osaka_dataframe = json_normalize(osaka_items) # flatten JSON

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter columns
osaka_filtered_columns = ['venue.name', 'venue.categories'] + [col for col in osaka_dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
osaka_dataframe_filtered = osaka_dataframe.loc[:, osaka_filtered_columns]

# filter the category for each row
osaka_dataframe_filtered['venue.categories'] = osaka_dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
osaka_dataframe_filtered.columns = [col.split('.')[-1] for col in osaka_dataframe_filtered.columns]

osaka_dataframe_filtered.head(25)
# Out:
# <ipython-input-88-76ad0fa7d9c1>:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   osaka_dataframe = json_normalize(osaka_items) # flatten JSON
#                                          name                 categories  \
# 0                     Indian Curry (インデアンカレー)  Japanese Curry Restaurant
# 1                    Kyu Yam Tetsudou (旧ヤム鐵道)  Japanese Curry Restaurant
# 2                  Rilakkuma Store (リラックマストア)                 Hobby Shop
# 3              Shin-Umeda Shokudogai (新梅田食道街)                 Food Court
# 4                            Honmiyake (本みやけ)            Nabe Restaurant
# 5                                     Y・C 梅田店                       Café
# 6              Kushikatsu Matsuba (串かつ松葉 総本店)      Kushikatsu Restaurant
# 7                             Hanadako (はなだこ)             Takoyaki Place
# 8                                     ポンガラカレー      Sri Lankan Restaurant
# 9         Yodobashi-Umeda (ヨドバシカメラ マルチメディア梅田)          Electronics Store
# 10                         スヌーピータウンショップ 大阪梅田店           Toy / Game Store
# 11        Maruzen & Junkudo (MARUZEN&ジュンク堂書店)                  Bookstore
# 12                    Qu'il fait bon (キルフェボン)               Dessert Shop
# 13                Kushikatsu Yoneya (串かつ ヨネヤ)      Kushikatsu Restaurant
# 14               Ueshima Coffee House (上島珈琲店)                Coffee Shop
# 15                Negiyaki Yamamoto (ねぎ焼やまもと)     Okonomiyaki Restaurant
# 16                      Okonomiyaki Kiji (きじ)     Okonomiyaki Restaurant
# 17                                   カレーハウスK2  Japanese Curry Restaurant
# 18                               Yukari (ゆかり)     Okonomiyaki Restaurant
# 19          Hankyu Department Store (阪急うめだ本店)           Department Store
# 20  InterContinental Osaka (インターコンチネンタルホテル大阪)                      Hotel
# 21                              TOWER RECORDS                Record Shop
# 22                     Theatre Umeda (テアトル梅田)              Movie Theater
# 23                         Daiso (ダイソー 大阪梅田店)             Discount Store
# 24                    ベルジャンビアプラス ドルフィンズ umeda                   Beer Bar
#
#           address       crossStreet        lat         lng  \
# 0         北区芝田1-3      阪急三番街 南館 B2F  34.705035  135.498755
# 1       北区梅田3-1-3         LUCUA B2F  34.703723  135.496843
# 2       北区芝田1-1-3       阪急三番街 北館 1F  34.705529  135.498330
# 3       北区角田町9-26               NaN  34.703826  135.497891
# 4       北区芝田1-1-3      阪急三番街 南館 B2F  34.704814  135.498132
# 5       北区角田町9-21         新梅田食道街 1F  34.703924  135.497496
# 6       北区角田町9-20         新梅田食道街 1F  34.703819  135.497767
# 7       北区角田町9-16         新梅田食道街 1F  34.702923  135.497682
# 8       北区角田町8-47        阪急サン広場 B1F  34.703289  135.498512
# 9        北区大深町1-1               NaN  34.704117  135.496552
# 10      北区芝田1-1-3      阪急三番街 北館 B1F  34.705961  135.498757
# 11      北区茶屋町7-20    チャスカ茶屋町 B1F-7F  34.707361  135.500167
# 12      北区大深町4-20   グランフロント大阪 南館 2F  34.704566  135.494814
# 13  北区角田町梅田地下街2-5   ホワイティうめだノースモール1  34.702914  135.499581
# 14      北区芝田1-1-3      阪急三番街 南館 B1F  34.705336  135.498476
# 15       北区角田町2-4       EST イーストエリア  34.704630  135.501110
# 16      北区角田町9-20            新梅田食堂街  34.703755  135.498262
# 17      北区芝田1-7-9             芝田商店街  34.707326  135.497696
# 18  北区角田町梅田地下街2-5  ホワイティうめだ ノースモール1  34.703754  135.499619
# 19       北区角田町8-7               NaN  34.702879  135.498470
# 20      北区大深町3-60               NaN  34.706430  135.494291
# 21     北区茶屋町10-12  NU Chayamachi 6F  34.707001  135.499119
# 22      北区茶屋町16-7         梅田ロフト B1F  34.708012  135.499627
# 23      北区茶屋町1-27  ABC-MART梅田ビル B2F  34.704533  135.499285
# 24      北区芝田1-5-2            大和ビル1F  34.706213  135.497419
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 34.70503520001439...        79   530-0012
# 1   [{'label': 'display', 'lat': 34.70372271536428...       210   530-8217
# 2   [{'label': 'display', 'lat': 34.70552912959402...        37   530-0012
# 3   [{'label': 'display', 'lat': 34.70382642951151...       171   530-0017
# 4   [{'label': 'display', 'lat': 34.704814, 'lng':...        62   530-0012
# 5   [{'label': 'display', 'lat': 34.70392392093758...       166   530-0017
# 6   [{'label': 'display', 'lat': 34.70381887442366...       172   530-0017
# 7   [{'label': 'display', 'lat': 34.70292288174605...       272   530-0017
# 8   [{'label': 'display', 'lat': 34.70328883050338...       236   530-0017
# 9   [{'label': 'display', 'lat': 34.70411746895576...       190   530-0011
# 10  [{'label': 'display', 'lat': 34.70596127008068...        97   530-0012
# 11  [{'label': 'display', 'lat': 34.707361, 'lng':...       299   530-0013
# 12  [{'label': 'display', 'lat': 34.70456550818748...       302   530-0011
# 13  [{'label': 'display', 'lat': 34.70291448535241...       309   530-0017
# 14  [{'label': 'display', 'lat': 34.70533583308812...        45   530-0012
# 15  [{'label': 'display', 'lat': 34.70463, 'lng': ...       298   530-0017
# 16  [{'label': 'display', 'lat': 34.703755, 'lng':...       180        NaN
# 17  [{'label': 'display', 'lat': 34.70732621411331...       220   530-0012
# 18  [{'label': 'display', 'lat': 34.70375352992175...       233        NaN
# 19  [{'label': 'display', 'lat': 34.70287904712021...       280   530-8350
# 20  [{'label': 'display', 'lat': 34.70642965492682...       357   530-0011
# 21  [{'label': 'display', 'lat': 34.70700125161271...       210   530-0013
# 22  [{'label': 'display', 'lat': 34.70801208509772...       331   530-0013
# 23  [{'label': 'display', 'lat': 34.70453325589041...       151   530-0013
# 24  [{'label': 'display', 'lat': 34.70621346225071...       107   530-0012
#
#     cc neighborhood city state country  \
# 0   JP           梅田  大阪市   大阪府      日本
# 1   JP          NaN  大阪市   大阪府      日本
# 2   JP          NaN  大阪市   大阪府      日本
# 3   JP          NaN  大阪市   大阪府      日本
# 4   JP           梅田  大阪市   大阪府      日本
# 5   JP           梅田  大阪市   大阪府      日本
# 6   JP          NaN  大阪市   大阪府      日本
# 7   JP          NaN  大阪市   大阪府      日本
# 8   JP          NaN  大阪市   大阪府      日本
# 9   JP           北区  大阪市   大阪府      日本
# 10  JP           梅田  大阪市   大阪府      日本
# 11  JP          NaN  大阪市   大阪府      日本
# 12  JP          NaN  大阪市   大阪府      日本
# 13  JP          NaN  大阪市   大阪府      日本
# 14  JP          NaN  大阪市   大阪府      日本
# 15  JP          NaN  大阪市   大阪府      日本
# 16  JP           梅田  大阪市   大阪府      日本
# 17  JP          NaN  大阪市   大阪府      日本
# 18  JP           梅田  大阪市   大阪府      日本
# 19  JP           梅田  大阪市   大阪府      日本
# 20  JP          NaN  大阪市   大阪府      日本
# 21  JP          NaN  大阪市   大阪府      日本
# 22  JP           梅田  大阪市   大阪府      日本
# 23  JP           梅田  大阪市   大阪府      日本
# 24  JP          NaN  大阪市   大阪府      日本
#
#                                      formattedAddress  \
# 0    [北区芝田1-3 (阪急三番街 南館 B2F), 大阪市, 大阪府, 530-0012, 日本]
# 1     [北区梅田3-1-3 (LUCUA B2F), 大阪市, 大阪府, 530-8217, 日本]
# 2   [北区芝田1-1-3 (阪急三番街 北館 1F), 大阪市, 大阪府, 530-0012, 日本]
# 3                 [北区角田町9-26, 大阪市, 大阪府, 530-0017, 日本]
# 4   [北区芝田1-1-3 (阪急三番街 南館 B2F), 大阪市, 大阪府, 530-0012,...
# 5     [北区角田町9-21 (新梅田食道街 1F), 大阪市, 大阪府, 530-0017, 日本]
# 6     [北区角田町9-20 (新梅田食道街 1F), 大阪市, 大阪府, 530-0017, 日本]
# 7     [北区角田町9-16 (新梅田食道街 1F), 大阪市, 大阪府, 530-0017, 日本]
# 8    [北区角田町8-47 (阪急サン広場 B1F), 大阪市, 大阪府, 530-0017, 日本]
# 9                  [北区大深町1-1, 大阪市, 大阪府, 530-0011, 日本]
# 10  [北区芝田1-1-3 (阪急三番街 北館 B1F), 大阪市, 大阪府, 530-0012,...
# 11  [北区茶屋町7-20 (チャスカ茶屋町 B1F-7F), 大阪市, 大阪府, 530-001...
# 12  [北区大深町4-20 (グランフロント大阪 南館 2F), 大阪市, 大阪府, 530-00...
# 13  [北区角田町梅田地下街2-5 (ホワイティうめだノースモール1), 大阪市, 大阪府, 53...
# 14  [北区芝田1-1-3 (阪急三番街 南館 B1F), 大阪市, 大阪府, 530-0012,...
# 15   [北区角田町2-4 (EST イーストエリア), 大阪市, 大阪府, 530-0017, 日本]
# 16                 [北区角田町9-20 (新梅田食堂街), 大阪市, 大阪府, 日本]
# 17        [北区芝田1-7-9 (芝田商店街), 大阪市, 大阪府, 530-0012, 日本]
# 18   [北区角田町梅田地下街2-5 (ホワイティうめだ ノースモール1), 大阪市, 大阪府, 日本]
# 19                 [北区角田町8-7, 大阪市, 大阪府, 530-8350, 日本]
# 20                [北区大深町3-60, 大阪市, 大阪府, 530-0011, 日本]
# 21  [北区茶屋町10-12 (NU Chayamachi 6F), 大阪市, 大阪府, 530-...
# 22    [北区茶屋町16-7 (梅田ロフト B1F), 大阪市, 大阪府, 530-0013, 日本]
# 23  [北区茶屋町1-27 (ABC-MART梅田ビル B2F), 大阪市, 大阪府, 530-0...
# 24       [北区芝田1-5-2 (大和ビル1F), 大阪市, 大阪府, 530-0012, 日本]
#
#                           id
# 0   4b5bb438f964a520181129e3
# 1   5517b1da498e650d9b08ff4e
# 2   4c0e1c46d64c0f47269c275d
# 3   4b63b4adf964a5203b8d2ae3
# 4   4b9092b6f964a520999033e3
# 5   4d92ec00fa1ef04d15c160c7
# 6   4c482e8776d72d7faf733f4d
# 7   4b57c014f964a520333f28e3
# 8   5701e824cd10cda211bd0c72
# 9   4b5aad26f964a52068d028e3
# 10  4baee215f964a52072df3be3
# 11  4d05583b30a58cfaf3e3a4e7
# 12  5177a32fe4b0621d2d7d7ab5
# 13  4d7c991c7498a1cdd09780fc
# 14  51274939183f2b48c2de4ee4
# 15  4baf1541f964a52069ea3be3
# 16  4b6262a7f964a52060452ae3
# 17  4bf606f5004ed13adee241a0
# 18  4c16561c82a3c9b60c2100f9
# 19  4b57beb3f964a520f13e28e3
# 20  513706d1e4b0cd1d4ae65386
# 21  4b63f694f964a520f4982ae3
# 22  4b650a6ef964a52006e12ae3
# 23  552f9ae1498e2f17bce2577e
# 24  4c41a05fda3dc928ef23c9b9

# %%
osaka_venues_map = folium.Map(osaka_location=[osaka_latitude, osaka_longitude], zoom_start=15) # generate map centred around Umeda Station


# add Umeda as a red circle mark
folium.CircleMarker(
    [osaka_latitude, osaka_longitude],
    radius=10,
    popup='Umeda Station',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(osaka_venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(osaka_dataframe_filtered.head(10).lat, osaka_dataframe_filtered.lng, osaka_dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(osaka_venues_map)

# display map
osaka_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_aca47b2572ce443f8b9e25aa3e07100f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_aca47b2572ce443f8b9e25aa3e07100f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_aca47b2572ce443f8b9e25aa3e07100f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_aca47b2572ce443f8b9e25aa3e07100f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# #### Sannomiya Station, Kobe, Japan Analysis <a name="Sannomiya Station, Kobe, Japan Analysis "></a>

# %%
## Get Coordinates of Sannomiya Station, Kobe, Japan

kobe_address = 'Sannomiya Station, Kobe, Japan'

geolocator = Nominatim(user_agent="foursquare_agent")
kobe_location = geolocator.geocode(kobe_address)
kobe_latitude = kobe_location.latitude
kobe_longitude = kobe_location.longitude
print('The latitude and longitude for Sannomiya Station is:', kobe_latitude, kobe_longitude)
# Out:
# The latitude and longitude for Sannomiya Station is: 34.6933427 135.1952946

# %%
# Identify top 10 popular venue categories and subsequent top 10 venues around Sannomiya Station, Kobe, Japan
kobe_latitude = kobe_location.latitude
kobe_longitude = kobe_location.longitude
radius = 1000
LIMIT = 25
kobe_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, kobe_latitude, kobe_longitude, VERSION, radius, LIMIT)
kobe_url

kobe_results = requests.get(kobe_url).json()
'There are {} around Sannomiya Station, Kobe, Japan.'.format(len(kobe_results['response']['groups'][0]['items']))

kobe_items = kobe_results['response']['groups'][0]['items']
kobe_items[0]

kobe_dataframe = json_normalize(kobe_items) # flatten JSON

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter columns
kobe_filtered_columns = ['venue.name', 'venue.categories'] + [col for col in kobe_dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
kobe_dataframe_filtered = kobe_dataframe.loc[:, kobe_filtered_columns]

# filter the category for each row
kobe_dataframe_filtered['venue.categories'] = kobe_dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
kobe_dataframe_filtered.columns = [col.split('.')[-1] for col in kobe_dataframe_filtered.columns]

kobe_dataframe_filtered.head(25)
# Out:
# <ipython-input-91-9b2bf6a62e54>:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   kobe_dataframe = json_normalize(kobe_items) # flatten JSON
#                                           name                 categories  \
# 0             Nishimura's Coffee (にしむら珈琲店 三宮店)                Coffee Shop
# 1                              Juban (十番 三ノ宮店)         Donburi Restaurant
# 2                                         ビゴの店                     Bakery
# 3                              CAFE KESHiPEARL                       Café
# 4                  Kobe Kokusai Hall (こくさいホール)               Concert Hall
# 5                                    モロゾフ 神戸本店                       Café
# 6                                    グリル一平 三宮店         Yoshoku Restaurant
# 7                            Baan Thai (バーンタイ)            Thai Restaurant
# 8                                    スタンドGONTA                  Gastropub
# 9                               たこ焼たちばな さんプラザ店             Takoyaki Place
# 10  Boulangerie Comme Chinois (ブランジェリー コム シノワ)                     Bakery
# 11                Isuzu Bakery (イスズベーカリー 北野坂店)                     Bakery
# 12                       Cascade カスカード さんプラザ本店                     Bakery
# 13                       Burger King (バーガーキング)       Fast Food Restaurant
# 14  Baskin-Robbins (サーティワン アイスクリーム 三宮フラワーロード店)             Ice Cream Shop
# 15                                Savoy (サヴォイ)  Japanese Curry Restaurant
# 16                                   トミーズ 三宮東店                     Bakery
# 17                                      神戸珈琲物語                       Café
# 18                                  スタンドGONTA２                        Bar
# 19                          Lashinbang (らしんばん)                 Hobby Shop
# 20                                 Red Rock 本店                 Steakhouse
# 21                                    土佐清水ワールド         Seafood Restaurant
# 22           Kobe International House (神戸国際会館)          Convention Center
# 23                             イスズベーカリー 生田ロード店                     Bakery
# 24   Hakata Motsunabe Yamaya (博多もつ鍋やまや JR三ノ宮店)        Japanese Restaurant
#
#            address         crossStreet        lat         lng  \
# 0     中央区琴ノ緒町5-3-5    グリーンシャポービル 1F-2F  34.695046  135.194363
# 1   中央区琴ノ緒町4-1-396                 高架下  34.695909  135.195769
# 2      中央区御幸通8-1-6          神戸国際会館 B2F  34.691689  135.195518
# 3     中央区御幸通6-1-25         もものき三宮ビル 2F  34.693536  135.197889
# 4      中央区御幸通8-1-6           神戸国際会館 2F  34.692156  135.195726
# 5      中央区三宮町1-8-1                 NaN  34.691860  135.193589
# 6    中央区琴ノ緒町5-5-26                 NaN  34.695920  135.194961
# 7     中央区北長狭通1-8-8          しんせい堂ビル 1F  34.693155  135.191862
# 8   中央区北長狭通1-31-26                 NaN  34.692407  135.192631
# 9      中央区三宮町1-8-1                 NaN  34.691845  135.193055
# 10    中央区御幸通7-1-16          三宮ビル南館 B1F  34.692294  135.196632
# 11   中央区中山手通1-8-18           三宮互陽ビル 1F  34.695140  135.192610
# 12    中央区三宮町1丁目8-1           さんプラザ B1F  34.691973  135.193809
# 13    中央区北長狭通1-2-4            KKサンキタビル  34.693845  135.193104
# 14    中央区御幸通8-1-14    フラワーロード、そごう新館 1F  34.692167  135.195043
# 15     中央区三宮町1-9-1     三宮センタープラザ東館 B1F  34.692109  135.192790
# 16    中央区琴ノ緒町4-1-5                 NaN  34.696087  135.195687
# 17    中央区三宮町1-10-1            三宮地下街703  34.691672  135.195520
# 18   中央区琴ノ緒町5-4-23          サンデンビル B1F  34.695835  135.194702
# 19     中央区三宮町1-9-1       センタープラザ東館203号  34.691892  135.192687
# 20  中央区北長狭通1-31-33           三宮阪急西口商店街  34.692514  135.191992
# 21     中央区雲井通5-3-1             サンパル 1F  34.695834  135.197296
# 22     中央区御幸通8-1-6                 NaN  34.692200  135.195950
# 23   中央区北長狭通2-1-14              玉広ビル1F  34.692472  135.191595
# 24     中央区布引町4-1-1  JR三ノ宮駅構内ダイニングロード2F  34.694452  135.194364
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 34.69504555207305...       207   651-0094
# 1   [{'label': 'display', 'lat': 34.695909, 'lng':...       288   651-0094
# 2   [{'label': 'display', 'lat': 34.69168869768715...       185   651-0087
# 3   [{'label': 'display', 'lat': 34.69353586057077...       238   651-0087
# 4   [{'label': 'display', 'lat': 34.69215640015317...       137   651-0087
# 5   [{'label': 'display', 'lat': 34.69186013890782...       227   650-0021
# 6   [{'label': 'display', 'lat': 34.69592032388635...       288   651-0094
# 7   [{'label': 'display', 'lat': 34.69315470395841...       314   650-0012
# 8   [{'label': 'display', 'lat': 34.69240697352583...       265   650-0012
# 9   [{'label': 'display', 'lat': 34.69184497177562...       264        NaN
# 10  [{'label': 'display', 'lat': 34.69229381877383...       169   651-0087
# 11  [{'label': 'display', 'lat': 34.69514, 'lng': ...       316   650-0004
# 12  [{'label': 'display', 'lat': 34.69197300274554...       204   650-0021
# 13  [{'label': 'display', 'lat': 34.69384524927225...       208   650-0012
# 14  [{'label': 'display', 'lat': 34.69216749492051...       132   651-0087
# 15  [{'label': 'display', 'lat': 34.69210942609942...       267   651-0021
# 16  [{'label': 'display', 'lat': 34.69608696548509...       307        NaN
# 17  [{'label': 'display', 'lat': 34.69167184716821...       187        NaN
# 18  [{'label': 'display', 'lat': 34.69583492424095...       282        NaN
# 19  [{'label': 'display', 'lat': 34.69189238211088...       288   650-0021
# 20  [{'label': 'display', 'lat': 34.69251392541711...       316   650-0012
# 21  [{'label': 'display', 'lat': 34.69583362572143...       332   651-0096
# 22  [{'label': 'display', 'lat': 34.6922, 'lng': 1...       140   651-0087
# 23  [{'label': 'display', 'lat': 34.69247194741839...       352   650-0012
# 24  [{'label': 'display', 'lat': 34.69445213304209...       150   651-0097
#
#     cc city state country                                   formattedAddress  \
# 0   JP  神戸市   兵庫県      日本  [中央区琴ノ緒町5-3-5 (グリーンシャポービル 1F-2F), 神戸市, 兵庫県, 65...
# 1   JP  神戸市   兵庫県      日本     [中央区琴ノ緒町4-1-396 (高架下), 神戸市, 兵庫県, 651-0094, 日本]
# 2   JP  神戸市   兵庫県      日本  [中央区御幸通8-1-6 (神戸国際会館 B2F), 神戸市, 兵庫県, 651-0087,...
# 3   JP  神戸市   兵庫県      日本  [中央区御幸通6-1-25 (もものき三宮ビル 2F), 神戸市, 兵庫県, 651-008...
# 4   JP  神戸市   兵庫県      日本  [中央区御幸通8-1-6 (神戸国際会館 2F), 神戸市, 兵庫県, 651-0087, 日本]
# 5   JP  神戸市   兵庫県      日本              [中央区三宮町1-8-1, 神戸市, 兵庫県, 650-0021, 日本]
# 6   JP  神戸市   兵庫県      日本            [中央区琴ノ緒町5-5-26, 神戸市, 兵庫県, 651-0094, 日本]
# 7   JP  神戸市   兵庫県      日本  [中央区北長狭通1-8-8 (しんせい堂ビル 1F), 神戸市, 兵庫県, 650-0012...
# 8   JP  神戸市   兵庫県      日本           [中央区北長狭通1-31-26, 神戸市, 兵庫県, 650-0012, 日本]
# 9   JP  神戸市   兵庫県      日本                        [中央区三宮町1-8-1, 神戸市, 兵庫県, 日本]
# 10  JP  神戸市   兵庫県      日本  [中央区御幸通7-1-16 (三宮ビル南館 B1F), 神戸市, 兵庫県, 651-0087...
# 11  JP  神戸市   兵庫県      日本  [中央区中山手通1-8-18 (三宮互陽ビル 1F), 神戸市, 兵庫県, 650-0004...
# 12  JP  神戸市   兵庫県      日本  [中央区三宮町1丁目8-1 (さんプラザ B1F), 神戸市, 兵庫県, 650-0021,...
# 13  JP  神戸市   兵庫県      日本  [中央区北長狭通1-2-4 (KKサンキタビル), 神戸市, 兵庫県, 650-0012, 日本]
# 14  JP  神戸市   兵庫県      日本  [中央区御幸通8-1-14 (フラワーロード、そごう新館 1F), 神戸市, 兵庫県, 65...
# 15  JP  神戸市   兵庫県      日本  [中央区三宮町1-9-1 (三宮センタープラザ東館 B1F), 神戸市, 兵庫県, 651-...
# 16  JP  神戸市   兵庫県      日本                       [中央区琴ノ緒町4-1-5, 神戸市, 兵庫県, 日本]
# 17  JP  神戸市   兵庫県      日本            [中央区三宮町1-10-1 (三宮地下街703), 神戸市, 兵庫県, 日本]
# 18  JP  神戸市   兵庫県      日本         [中央区琴ノ緒町5-4-23 (サンデンビル B1F), 神戸市, 兵庫県, 日本]
# 19  JP  神戸市   兵庫県      日本  [中央区三宮町1-9-1 (センタープラザ東館203号), 神戸市, 兵庫県, 650-00...
# 20  JP  神戸市   兵庫県      日本  [中央区北長狭通1-31-33 (三宮阪急西口商店街), 神戸市, 兵庫県, 650-001...
# 21  JP  神戸市   兵庫県      日本    [中央区雲井通5-3-1 (サンパル 1F), 神戸市, 兵庫県, 651-0096, 日本]
# 22  JP  神戸市   兵庫県      日本              [中央区御幸通8-1-6, 神戸市, 兵庫県, 651-0087, 日本]
# 23  JP  神戸市   兵庫県      日本   [中央区北長狭通2-1-14 (玉広ビル1F), 神戸市, 兵庫県, 650-0012, 日本]
# 24  JP  神戸市   兵庫県      日本  [中央区布引町4-1-1 (JR三ノ宮駅構内ダイニングロード2F), 神戸市, 兵庫県, 6...
#
#    neighborhood                        id
# 0           NaN  4b7bbb6df964a5203f6c2fe3
# 1           NaN  4bc6fb706501c9b60e8c3d29
# 2           NaN  4b9b3a42f964a52008fb35e3
# 3           NaN  4f3550da0cd6e71afa08b63c
# 4           NaN  4d0092f90457b1f7fc053278
# 5           NaN  4e5f2b4bd4c08cf7f597b98c
# 6           NaN  4e5647011495eb38e2057cb7
# 7           NaN  4d73496227ddb60c8fa9da1b
# 8           NaN  51ea2a8f498ed094a339ccab
# 9            三宮  4cf32b22e3b9a0930f924853
# 10          NaN  4c9edb328afca093e25a0516
# 11         Chuo  4c8c3ba6ec61bfb7a7fba041
# 12           三宮  4bee3e6cd355a5939fb70a60
# 13          NaN  50c296ade4b00ce4a3d1efbd
# 14          NaN  4bb31f9c4019a593088d37b8
# 15           三宮  4c3bed79933b0f475c7ae321
# 16          NaN  4c3260d57cc0c9b6743af09a
# 17          中央区  4ed875ad7ee506bd297bc8fa
# 18          NaN  53f45142498e10536fe42ed9
# 19          NaN  4c7340c713228cfa9b702d65
# 20          NaN  5128b592e4b004fb800c6bb4
# 21          NaN  55878f7d498edcdb43afb2c1
# 22          NaN  4b54ef8ef964a52002d427e3
# 23          NaN  4c88b312bbec6dcba8b8d558
# 24          NaN  547d2f67498e2e7d12bf048e

# %%
kobe_venues_map = folium.Map(kobe_location=[kobe_latitude, kobe_longitude], zoom_start=15) # generate map centred around Sannomiya Station


# add Sannomiya as a red circle mark
folium.CircleMarker(
    [kobe_latitude, kobe_longitude],
    radius=10,
    popup='Sannomiya',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(kobe_venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(kobe_dataframe_filtered.head(10).lat, kobe_dataframe_filtered.lng, kobe_dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(kobe_venues_map)

# display map
kobe_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_13a3d53fa0dc44a5b121e7352ecd5248%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_13a3d53fa0dc44a5b121e7352ecd5248%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_13a3d53fa0dc44a5b121e7352ecd5248%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_13a3d53fa0dc44a5b121e7352ecd5248%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ### Stage 2 -  Model Building and Comparison <a name="Stage 2 - Manual Interpretation, Model Building and Comparison"></a>

# %%
# comparison of data using K-means clustering with the same results from stage 1 to generate the 10 most popular venues

# %% [markdown]
# #### Umeda Station, Osaka, Japan Analysis (K-means) <a name="Umeda Station, Osaka, Japan Analysis (K-means) "></a>

# %%
# one hot encoding
osaka_onehot = pd.get_dummies(osaka_dataframe_filtered[['categories']], prefix="", prefix_sep="")

# add categories column back to dataframe
osaka_onehot['city'] = osaka_dataframe_filtered['city'] 

# move categories column to the first column
osaka_fixed_columns = [osaka_onehot.columns[-1]] + list(osaka_onehot.columns[:-1])
osaka_onehot = osaka_onehot[osaka_fixed_columns]

osaka_onehot.head()

osaka_onehot.shape

osaka_grouped = osaka_onehot.groupby('city').mean().reset_index()
osaka_grouped

osaka_grouped.shape


num_top_venues = 25

for city in osaka_grouped['city']:
    print("----"+city+"----")
    temp = osaka_grouped[osaka_grouped['city'] == city].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----大阪市----
#                         venue  freq
# 0      Okonomiyaki Restaurant  0.12
# 1   Japanese Curry Restaurant  0.12
# 2       Kushikatsu Restaurant  0.08
# 3                    Beer Bar  0.04
# 4                   Bookstore  0.04
# 5              Takoyaki Place  0.04
# 6       Sri Lankan Restaurant  0.04
# 7                 Record Shop  0.04
# 8             Nabe Restaurant  0.04
# 9               Movie Theater  0.04
# 10                      Hotel  0.04
# 11                 Hobby Shop  0.04
# 12                 Food Court  0.04
# 13          Electronics Store  0.04
# 14             Discount Store  0.04
# 15               Dessert Shop  0.04
# 16           Department Store  0.04
# 17                Coffee Shop  0.04
# 18                       Café  0.04
# 19           Toy / Game Store  0.04

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['city']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Popular Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Popular Venue'.format(ind+1))

# create a new dataframe
osaka_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
osaka_neighborhoods_venues_sorted['city'] = osaka_grouped['city']

for ind in np.arange(osaka_grouped.shape[0]):
    osaka_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(osaka_grouped.iloc[ind, :], num_top_venues)

osaka_neighborhoods_venues_sorted.head()
# Out:
#   city  1st Most Popular Venue     2nd Most Popular Venue  \
# 0  大阪市  Okonomiyaki Restaurant  Japanese Curry Restaurant
#
#   3rd Most Popular Venue 4th Most Popular Venue 5th Most Popular Venue  \
# 0  Kushikatsu Restaurant               Beer Bar              Bookstore
#
#   6th Most Popular Venue 7th Most Popular Venue 8th Most Popular Venue  \
# 0         Takoyaki Place  Sri Lankan Restaurant            Record Shop
#
#   9th Most Popular Venue 10th Most Popular Venue
# 0        Nabe Restaurant           Movie Theater

# %%
# set number of clusters
kclusters = 1

osaka_grouped_clustering = osaka_grouped.drop('city', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(osaka_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0], dtype=int32)

# %%
# add clustering labels
osaka_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

osaka_merged = osaka_dataframe_filtered

# merge osaka_grouped with osaka_data to add latitude/longitude for each city
osaka_merged = osaka_merged.join(osaka_neighborhoods_venues_sorted.set_index('city'), on='city')

osaka_merged.head() # check the last columns!
# Out:
#                              name                 categories    address  \
# 0         Indian Curry (インデアンカレー)  Japanese Curry Restaurant    北区芝田1-3
# 1        Kyu Yam Tetsudou (旧ヤム鐵道)  Japanese Curry Restaurant  北区梅田3-1-3
# 2      Rilakkuma Store (リラックマストア)                 Hobby Shop  北区芝田1-1-3
# 3  Shin-Umeda Shokudogai (新梅田食道街)                 Food Court  北区角田町9-26
# 4                Honmiyake (本みやけ)            Nabe Restaurant  北区芝田1-1-3
#
#     crossStreet        lat         lng  \
# 0  阪急三番街 南館 B2F  34.705035  135.498755
# 1     LUCUA B2F  34.703723  135.496843
# 2   阪急三番街 北館 1F  34.705529  135.498330
# 3           NaN  34.703826  135.497891
# 4  阪急三番街 南館 B2F  34.704814  135.498132
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 34.70503520001439...        79   530-0012  JP
# 1  [{'label': 'display', 'lat': 34.70372271536428...       210   530-8217  JP
# 2  [{'label': 'display', 'lat': 34.70552912959402...        37   530-0012  JP
# 3  [{'label': 'display', 'lat': 34.70382642951151...       171   530-0017  JP
# 4  [{'label': 'display', 'lat': 34.704814, 'lng':...        62   530-0012  JP
#
#    ...  1st Most Popular Venue     2nd Most Popular Venue  \
# 0  ...  Okonomiyaki Restaurant  Japanese Curry Restaurant
# 1  ...  Okonomiyaki Restaurant  Japanese Curry Restaurant
# 2  ...  Okonomiyaki Restaurant  Japanese Curry Restaurant
# 3  ...  Okonomiyaki Restaurant  Japanese Curry Restaurant
# 4  ...  Okonomiyaki Restaurant  Japanese Curry Restaurant
#
#   3rd Most Popular Venue 4th Most Popular Venue 5th Most Popular Venue  \
# 0  Kushikatsu Restaurant               Beer Bar              Bookstore
# 1  Kushikatsu Restaurant               Beer Bar              Bookstore
# 2  Kushikatsu Restaurant               Beer Bar              Bookstore
# 3  Kushikatsu Restaurant               Beer Bar              Bookstore
# 4  Kushikatsu Restaurant               Beer Bar              Bookstore
#
#   6th Most Popular Venue  7th Most Popular Venue 8th Most Popular Venue  \
# 0         Takoyaki Place   Sri Lankan Restaurant            Record Shop
# 1         Takoyaki Place   Sri Lankan Restaurant            Record Shop
# 2         Takoyaki Place   Sri Lankan Restaurant            Record Shop
# 3         Takoyaki Place   Sri Lankan Restaurant            Record Shop
# 4         Takoyaki Place   Sri Lankan Restaurant            Record Shop
#
#   9th Most Popular Venue 10th Most Popular Venue
# 0        Nabe Restaurant           Movie Theater
# 1        Nabe Restaurant           Movie Theater
# 2        Nabe Restaurant           Movie Theater
# 3        Nabe Restaurant           Movie Theater
# 4        Nabe Restaurant           Movie Theater
#
# [5 rows x 27 columns]

# %%
# create map

import matplotlib.cm as cm
import matplotlib.colors as colors

osaka_map_clusters = folium.Map(osaka_location=[osaka_latitude, osaka_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(osaka_merged['lat'], osaka_merged['lng'], osaka_merged['city'], osaka_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(osaka_map_clusters)
       
osaka_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_93832e0d229b47fa88b971dd8593d72c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_93832e0d229b47fa88b971dd8593d72c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_93832e0d229b47fa88b971dd8593d72c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_93832e0d229b47fa88b971dd8593d72c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# #### Sannomiya Station, Kobe, Japan Analysis (K-means) <a name="Sannomiya Station, Kobe, Japan Analysis (K-means)"></a>

# %%
# one hot encoding
kobe_onehot = pd.get_dummies(kobe_dataframe_filtered[['categories']], prefix="", prefix_sep="")

# add categories column back to dataframe
kobe_onehot['city'] = kobe_dataframe_filtered['city'] 

# move categories column to the first column
fixed_columns = [kobe_onehot.columns[-1]] + list(kobe_onehot.columns[:-1])
kobe_onehot = kobe_onehot[fixed_columns]

kobe_onehot.head()

kobe_onehot.shape

kobe_grouped = kobe_onehot.groupby('city').mean().reset_index()
kobe_grouped

kobe_grouped.shape


num_top_venues = 10

for city in kobe_grouped['city']:
    print("----"+city+"----")
    temp = kobe_grouped[kobe_grouped['city'] == city].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----神戸市----
#                        venue  freq
# 0                     Bakery  0.24
# 1                       Café  0.12
# 2             Ice Cream Shop  0.04
# 3            Thai Restaurant  0.04
# 4             Takoyaki Place  0.04
# 5                 Steakhouse  0.04
# 6         Seafood Restaurant  0.04
# 7        Japanese Restaurant  0.04
# 8  Japanese Curry Restaurant  0.04
# 9                 Hobby Shop  0.04

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['city']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Popular Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Popular Venue'.format(ind+1))

# create a new dataframe
kobe_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
kobe_neighborhoods_venues_sorted['city'] = kobe_grouped['city']

for ind in np.arange(kobe_grouped.shape[0]):
    kobe_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(kobe_grouped.iloc[ind, :], num_top_venues)

kobe_neighborhoods_venues_sorted.head()
# Out:
#   city 1st Most Popular Venue 2nd Most Popular Venue 3rd Most Popular Venue  \
# 0  神戸市                 Bakery                   Café         Ice Cream Shop
#
#   4th Most Popular Venue 5th Most Popular Venue 6th Most Popular Venue  \
# 0        Thai Restaurant         Takoyaki Place             Steakhouse
#
#   7th Most Popular Venue 8th Most Popular Venue     9th Most Popular Venue  \
# 0     Seafood Restaurant    Japanese Restaurant  Japanese Curry Restaurant
#
#   10th Most Popular Venue
# 0              Hobby Shop

# %%
# set number of clusters
kclusters = 1

kobe_grouped_clustering = kobe_grouped.drop('city', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(kobe_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0], dtype=int32)

# %%
# add clustering labels
kobe_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

kobe_merged = kobe_dataframe_filtered

# merge osaka_grouped with osaka_data to add latitude/longitude for each city
kobe_merged = kobe_merged.join(kobe_neighborhoods_venues_sorted.set_index('city'), on='city')

kobe_merged.head() # check the last columns!
# Out:
#                                name          categories         address  \
# 0  Nishimura's Coffee (にしむら珈琲店 三宮店)         Coffee Shop    中央区琴ノ緒町5-3-5
# 1                   Juban (十番 三ノ宮店)  Donburi Restaurant  中央区琴ノ緒町4-1-396
# 2                              ビゴの店              Bakery     中央区御幸通8-1-6
# 3                   CAFE KESHiPEARL                Café    中央区御幸通6-1-25
# 4       Kobe Kokusai Hall (こくさいホール)        Concert Hall     中央区御幸通8-1-6
#
#         crossStreet        lat         lng  \
# 0  グリーンシャポービル 1F-2F  34.695046  135.194363
# 1               高架下  34.695909  135.195769
# 2        神戸国際会館 B2F  34.691689  135.195518
# 3       もものき三宮ビル 2F  34.693536  135.197889
# 4         神戸国際会館 2F  34.692156  135.195726
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 34.69504555207305...       207   651-0094  JP
# 1  [{'label': 'display', 'lat': 34.695909, 'lng':...       288   651-0094  JP
# 2  [{'label': 'display', 'lat': 34.69168869768715...       185   651-0087  JP
# 3  [{'label': 'display', 'lat': 34.69353586057077...       238   651-0087  JP
# 4  [{'label': 'display', 'lat': 34.69215640015317...       137   651-0087  JP
#
#    ... 1st Most Popular Venue 2nd Most Popular Venue 3rd Most Popular Venue  \
# 0  ...                 Bakery                   Café         Ice Cream Shop
# 1  ...                 Bakery                   Café         Ice Cream Shop
# 2  ...                 Bakery                   Café         Ice Cream Shop
# 3  ...                 Bakery                   Café         Ice Cream Shop
# 4  ...                 Bakery                   Café         Ice Cream Shop
#
#   4th Most Popular Venue 5th Most Popular Venue 6th Most Popular Venue  \
# 0        Thai Restaurant         Takoyaki Place             Steakhouse
# 1        Thai Restaurant         Takoyaki Place             Steakhouse
# 2        Thai Restaurant         Takoyaki Place             Steakhouse
# 3        Thai Restaurant         Takoyaki Place             Steakhouse
# 4        Thai Restaurant         Takoyaki Place             Steakhouse
#
#    7th Most Popular Venue 8th Most Popular Venue     9th Most Popular Venue  \
# 0      Seafood Restaurant    Japanese Restaurant  Japanese Curry Restaurant
# 1      Seafood Restaurant    Japanese Restaurant  Japanese Curry Restaurant
# 2      Seafood Restaurant    Japanese Restaurant  Japanese Curry Restaurant
# 3      Seafood Restaurant    Japanese Restaurant  Japanese Curry Restaurant
# 4      Seafood Restaurant    Japanese Restaurant  Japanese Curry Restaurant
#
#   10th Most Popular Venue
# 0              Hobby Shop
# 1              Hobby Shop
# 2              Hobby Shop
# 3              Hobby Shop
# 4              Hobby Shop
#
# [5 rows x 27 columns]

# %%
# create map

kobe_map_clusters = folium.Map(kobe_location=[kobe_latitude, kobe_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(kobe_merged['lat'], kobe_merged['lng'], kobe_merged['city'], kobe_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(kobe_map_clusters)
       
kobe_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2a68b546ce1a4e72ba21194dba32dbf9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2a68b546ce1a4e72ba21194dba32dbf9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2a68b546ce1a4e72ba21194dba32dbf9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2a68b546ce1a4e72ba21194dba32dbf9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ### Stage 3 -  Model Execution <a name="Stage 2 - Model Execution"></a>

# %%
#Test the K-means Clustering model created in Step 2 by extending the parameters to include the following:
# - Most popular venue categories
# - Most popular venue within each category
# - search radius of 2,000m

# %% [markdown]
# #### Check on Shinagawa Station, Shinagawa, Japan  <a name="Check on Shinagawa Station, Shinagawa, Japan"></a>

# %%
## Get Coordinates of Shinagawa Station, Shinagawa, Japan

shinagawa_address = 'Shinagawa Station, Shinagawa, Japan'

geolocator = Nominatim(user_agent="foursquare_agent")
shinagawa_location = geolocator.geocode(shinagawa_address)
shinagawa_latitude = shinagawa_location.latitude
shinagawa_longitude = shinagawa_location.longitude
print('The latitude and longitude for Shinagawa Station is:', shinagawa_latitude, shinagawa_longitude)
# Out:
# The latitude and longitude for Shinagawa Station is: 35.6293681 139.73926908273415

# %%
# Identify top 25 popular venue categories and subsequent top 25 venues around Umeda Station, Osaka Japan
shinagawa_latitude = shinagawa_location.latitude
shinagawa_longitude= shinagawa_location.longitude
radius = 2000
LIMIT = 25
shinagawa_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, shinagawa_latitude, shinagawa_longitude, VERSION, radius, LIMIT)
shinagawa_url

shinagawa_results = requests.get(shinagawa_url).json()
'There are {} around osaka Station, Osaka, Japan.'.format(len(shinagawa_results['response']['groups'][0]['items']))

shinagawa_items = shinagawa_results['response']['groups'][0]['items']
shinagawa_items[0]

shinagawa_nearby_venues = json_normalize(shinagawa_items) # flatten JSON

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter columns
shinagawa_filtered_columns = ['venue.name', 'venue.categories'] + [col for col in shinagawa_nearby_venues.columns if col.startswith('venue.location.')] + ['venue.id']
shinagawa_dataframe_filtered = shinagawa_nearby_venues.loc[:, shinagawa_filtered_columns]

# filter the category for each row
shinagawa_dataframe_filtered['venue.categories'] = shinagawa_dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
shinagawa_dataframe_filtered.columns = [col.split('.')[-1] for col in shinagawa_dataframe_filtered.columns]

shinagawa_dataframe_filtered.head(25)
# Out:
# <ipython-input-102-808b8bad969a>:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   shinagawa_nearby_venues = json_normalize(shinagawa_items) # flatten JSON
#                                                  name  \
# 0                                            Barbacoa
# 1                                       Rojiura (路地裏)
# 2   Strings by InterContinental Tokyo (ストリングスホテル東京...
# 3                                Saza Coffee (サザコーヒー)
# 4                                         El Caliente
# 5                                     Antenna America
# 6                              T・ジョイPRINCE品川 IMAXシアター
# 7                          Okonomiyaki Kiji (お好み焼 きじ)
# 8                              Tsubame Grill (つばめグリル)
# 9          Maxell Aqua Park Shinagawa (マクセル アクアパーク品川)
# 10                              Salma Tikka & Biryani
# 11                                  魚介ビストロ sasaya BYO
# 12                                 Outback Steakhouse
# 13     The Prince Sakura Tower Tokyo (ザ・プリンスさくらタワー東京)
# 14              Grand Central Oyster Bar & Restaurant
# 15                                         カレーハウス キラリ
# 16                                      Harvesterrace
# 17                Luxe Dining Hapuna (リュクス ダイニング ハプナ)
# 18                        Uogashi Nihon-Ichi (魚がし日本一)
# 19                              Ajidokoro Yu (味どころ 遊)
# 20                     Boulangerie Asanoya (ブランジェ浅野屋)
# 21                                          Starbucks
# 22                            Anna Miller's (アンナミラーズ)
# 23                                         breadworks
# 24                                      DEAN & DELUCA
#
#                    categories    address                crossStreet  \
# 0        Brazilian Restaurant  高輪4-10-18              ウィング高輪WEST 3F
# 1                    Sake Bar    港南2-2-4                        NaN
# 2                       Hotel   港南2-16-1        品川イーストワンタワー 26F-32F
# 3                 Coffee Shop  高輪3-26-27                 ecute品川 1F
# 4          Mexican Restaurant   港南2-18-1                   アトレ品川 4F
# 5                    Beer Bar   港南2-18-1                   アトレ品川 3F
# 6               Movie Theater  高輪4-10-30      品川プリンスホテル アネックスタワー 6F
# 7      Okonomiyaki Restaurant   港南2-3-13                品川フロントビル 2F
# 8           German Restaurant  高輪4-10-26                        NaN
# 9                    Aquarium  高輪4-10-30                 品川プリンスホテル内
# 10          Indian Restaurant  高輪4-22-11                ヴィラージュ高輪 1F
# 11                  Gastropub  高輪3-26-33           パル品川 2F 品川魚貝センター
# 12                 Steakhouse   高輪4-10-8               京急EXイン高輪 B1F
# 13                      Hotel     3-13-1                        NaN
# 14         Seafood Restaurant   港南2-18-1                   アトレ品川 4F
# 15  Japanese Curry Restaurant  港南2-14-10                品川駅前港南ビル 2F
# 16                       Café    高輪4-8-4               モンベル高輪ビル B1F
# 17                     Buffet  高輪4-10-30        品川プリンスホテル メインタワー 1F
# 18           Sushi Restaurant  高輪3-26-27                 エキュート品川サウス
# 19        Japanese Restaurant   港南2-2-16                  谷田企画ビル 3F
# 20                     Bakery   港南2-18-1  アトレ品川 3F Food&Time Isetan
# 21                Coffee Shop   港南2-1-78           品川駅 改札外/JR東海品川駅店
# 22                   Pie Shop  高輪4-10-18              ウィング高輪WEST 2F
# 23                     Bakery  高輪3-26-27  ecute品川 1F Variety Market
# 24              Grocery Store   港南2-18-1                   アトレ品川 2F
#
#           lat         lng                                     labeledLatLngs  \
# 0   35.628515  139.736955  [{'label': 'display', 'lat': 35.6285145, 'lng'...
# 1   35.629259  139.742355  [{'label': 'display', 'lat': 35.62925904771133...
# 2   35.627907  139.740726  [{'label': 'display', 'lat': 35.6279075, 'lng'...
# 3   35.628469  139.739426  [{'label': 'display', 'lat': 35.62846913172101...
# 4   35.629079  139.740651  [{'label': 'display', 'lat': 35.629079, 'lng':...
# 5   35.629074  139.740635  [{'label': 'display', 'lat': 35.62907378251761...
# 6   35.627634  139.735805  [{'label': 'display', 'lat': 35.62763423300281...
# 7   35.629213  139.744264  [{'label': 'display', 'lat': 35.62921307281103...
# 8   35.627690  139.737364  [{'label': 'display', 'lat': 35.62768970765473...
# 9   35.627830  139.735090  [{'label': 'display', 'lat': 35.62783, 'lng': ...
# 10  35.625819  139.737571  [{'label': 'display', 'lat': 35.62581889928027...
# 11  35.629487  139.737798  [{'label': 'display', 'lat': 35.62948734146799...
# 12  35.629075  139.735313  [{'label': 'display', 'lat': 35.629075, 'lng':...
# 13  35.630924  139.735468  [{'label': 'display', 'lat': 35.6309235, 'lng'...
# 14  35.628890  139.740772  [{'label': 'display', 'lat': 35.62888999119544...
# 15  35.628628  139.742024  [{'label': 'display', 'lat': 35.62862826482015...
# 16  35.629198  139.733902  [{'label': 'display', 'lat': 35.62919781313389...
# 17  35.628001  139.736780  [{'label': 'display', 'lat': 35.628001464121, ...
# 18  35.627898  139.738877  [{'label': 'display', 'lat': 35.627898, 'lng':...
# 19  35.629202  139.742011  [{'label': 'display', 'lat': 35.629202, 'lng':...
# 20  35.629049  139.740636  [{'label': 'display', 'lat': 35.62904941643494...
# 21  35.629016  139.740015  [{'label': 'display', 'lat': 35.62901604105072...
# 22  35.628772  139.737102  [{'label': 'display', 'lat': 35.62877198652205...
# 23  35.628586  139.739403  [{'label': 'display', 'lat': 35.62858628756979...
# 24  35.628944  139.741065  [{'label': 'display', 'lat': 35.62894440366545...
#
#     distance postalCode  cc neighborhood city state country  \
# 0        229   108-0074  JP  高輪, 東京, 東京都   東京   東京都      日本
# 1        279   108-0075  JP          NaN   東京   東京都      日本
# 2        209   108-8282  JP          NaN   港区   東京都      日本
# 3        101   108-0074  JP          NaN   東京   東京都      日本
# 4        129   108-0075  JP          NaN   東京   東京都      日本
# 5        127   108-0075  JP          NaN   東京   東京都      日本
# 6        368   108-0074  JP           港区   東京   東京都      日本
# 7        452   108-0075  JP          NaN   東京   東京都      日本
# 8        254   108-8474  JP          五反田   東京   東京都      日本
# 9        415   108-8611  JP           高輪   東京   東京都      日本
# 10       423   108-0074  JP          NaN   東京   東京都      日本
# 11       133   108-0074  JP          NaN   東京   東京都      日本
# 12       359   108-0074  JP          NaN   東京   東京都      日本
# 13       385   108-8612  JP           高輪   東京   東京都      日本
# 14       146   108-0075  JP          NaN   東京   東京都      日本
# 15       262   108-0075  JP          NaN   東京   東京都      日本
# 16       485   108-0074  JP          NaN   東京   東京都      日本
# 17       271   108-8611  JP          NaN   東京   東京都      日本
# 18       167   108-0074  JP          NaN   東京   東京都      日本
# 19       248   108-0075  JP          NaN   東京   東京都      日本
# 20       128        NaN  JP          NaN   東京   東京都      日本
# 21        78   108-0075  JP           品川   東京   東京都      日本
# 22       206   108-0074  JP          NaN   東京   東京都      日本
# 23        87   108-0074  JP          NaN   東京   東京都      日本
# 24       169   108-0075  JP          NaN   東京   東京都      日本
#
#                                      formattedAddress  \
# 0   [高輪4-10-18 (ウィング高輪WEST 3F), 港区, 東京都, 108-0074,...
# 1                    [港南2-2-4, 港区, 東京都, 108-0075, 日本]
# 2   [港南2-16-1 (品川イーストワンタワー 26F-32F), 港区, 東京都, 108-...
# 3     [高輪3-26-27 (ecute品川 1F), 港区, 東京都, 108-0074, 日本]
# 4        [港南2-18-1 (アトレ品川 4F), 港区, 東京都, 108-0075, 日本]
# 5        [港南2-18-1 (アトレ品川 3F), 港区, 東京都, 108-0075, 日本]
# 6   [高輪4-10-30 (品川プリンスホテル アネックスタワー 6F), 港区, 東京都, 1...
# 7     [港南2-3-13 (品川フロントビル 2F), 港区, 東京都, 108-0075, 日本]
# 8                  [高輪4-10-26, 港区, 東京都, 108-8474, 日本]
# 9     [高輪4-10-30 (品川プリンスホテル内), 港区, 東京都, 108-8611, 日本]
# 10   [高輪4-22-11 (ヴィラージュ高輪 1F), 港区, 東京都, 108-0074, 日本]
# 11  [高輪3-26-33 (パル品川 2F 品川魚貝センター), 港区, 東京都, 108-00...
# 12   [高輪4-10-8 (京急EXイン高輪 B1F), 港区, 東京都, 108-0074, 日本]
# 13                    [3-13-1, 港区, 東京都, 108-8612, 日本]
# 14       [港南2-18-1 (アトレ品川 4F), 港区, 東京都, 108-0075, 日本]
# 15   [港南2-14-10 (品川駅前港南ビル 2F), 港区, 東京都, 108-0075, 日本]
# 16    [高輪4-8-4 (モンベル高輪ビル B1F), 港区, 東京都, 108-0074, 日本]
# 17  [高輪4-10-30 (品川プリンスホテル メインタワー 1F), 港区, 東京都, 108...
# 18    [高輪3-26-27 (エキュート品川サウス), 港区, 東京都, 108-0074, 日本]
# 19      [港南2-2-16 (谷田企画ビル 3F), 港区, 東京都, 108-0075, 日本]
# 20  [港南2-18-1 (アトレ品川 3F Food&Time Isetan), 港区, 東京都...
# 21  [港南2-1-78 (品川駅 改札外/JR東海品川駅店), 港区, 東京都, 108-007...
# 22  [高輪4-10-18 (ウィング高輪WEST 2F), 港区, 東京都, 108-0074,...
# 23  [高輪3-26-27 (ecute品川 1F Variety Market), 港区, 東京...
# 24       [港南2-18-1 (アトレ品川 2F), 港区, 東京都, 108-0075, 日本]
#
#                           id
# 0   55530f91498eca9bfbb5737b
# 1   4b864e99f964a520798531e3
# 2   4b1df999f964a520971624e3
# 3   4b8da688f964a5206f0633e3
# 4   517b9623498e982bac210a7a
# 5   582aeb758f3b464e8309c081
# 6   5780cbb3498e2b2953661723
# 7   4d05884937036dcb5d4a17fb
# 8   4b495939f964a5200f6e26e3
# 9   4b7775a0f964a520bf9b2ee3
# 10  4bbaa95053649c74755849fb
# 11  4e281a9352b1c37d35be13cd
# 12  4bf507a0e5eba59308462090
# 13  56839b12498e2b96d51b5328
# 14  4b9efa7df964a520040e37e3
# 15  4b6b8e5bf964a520b10f2ce3
# 16  51cd666b498e4f7da5dbd4e4
# 17  4b9e17f6f964a52045ca36e3
# 18  4dd1f6d01520b73b28b0244a
# 19  4bfdddc7b68d0f47b27fe957
# 20  583399169850a010053a627a
# 21  5a3315a060d11b58b2983c92
# 22  4b454bc2f964a520130a26e3
# 23  517e173de4b00f3e186d8c2d
# 24  4b514d4ff964a520514a27e3

# %%
shinagawa_venues_map = folium.Map(shinagawa_location=[shinagawa_latitude, shinagawa_longitude], zoom_start=15) # generate map centred around Shinagawa Station


# add Shinagawa as a red circle mark
folium.CircleMarker(
    [osaka_latitude, osaka_longitude],
    radius=10,
    popup='Shinagawa Station',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(shinagawa_venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(shinagawa_dataframe_filtered.head(25).lat, shinagawa_dataframe_filtered.lng, shinagawa_dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(shinagawa_venues_map)

# display map
shinagawa_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ab3a89f2892a476eb66ee51edb9c791a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ab3a89f2892a476eb66ee51edb9c791a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ab3a89f2892a476eb66ee51edb9c791a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ab3a89f2892a476eb66ee51edb9c791a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
# one hot encoding
shinagawa_onehot = pd.get_dummies(shinagawa_dataframe_filtered[['categories']], prefix="", prefix_sep="")

# add categories column back to dataframe
shinagawa_onehot['city'] = shinagawa_dataframe_filtered['city'] 

# move categories column to the first column
shinagawa_fixed_columns = [shinagawa_onehot.columns[-1]] + list(shinagawa_onehot.columns[:-1])
shinagawa_onehot = shinagawa_onehot[shinagawa_fixed_columns]

shinagawa_onehot.head()

shinagawa_onehot.shape

shinagawa_grouped = shinagawa_onehot.groupby('city').mean().reset_index()
shinagawa_grouped

shinagawa_grouped.shape


num_top_venues = 25

for city in shinagawa_grouped['city']:
    print("----"+city+"----")
    temp = shinagawa_grouped[shinagawa_grouped['city'] == city].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----東京----
#                         venue  freq
# 0                 Coffee Shop  0.08
# 1                      Bakery  0.08
# 2                    Aquarium  0.04
# 3   Japanese Curry Restaurant  0.04
# 4                  Steakhouse  0.04
# 5          Seafood Restaurant  0.04
# 6                    Sake Bar  0.04
# 7                    Pie Shop  0.04
# 8      Okonomiyaki Restaurant  0.04
# 9               Movie Theater  0.04
# 10         Mexican Restaurant  0.04
# 11        Japanese Restaurant  0.04
# 12          Indian Restaurant  0.04
# 13                      Hotel  0.04
# 14              Grocery Store  0.04
# 15          German Restaurant  0.04
# 16                  Gastropub  0.04
# 17                       Café  0.04
# 18                     Buffet  0.04
# 19       Brazilian Restaurant  0.04
# 20                   Beer Bar  0.04
# 21           Sushi Restaurant  0.04
#
#
# ----港区----
#                         venue  freq
# 0                       Hotel   1.0
# 1                    Aquarium   0.0
# 2   Japanese Curry Restaurant   0.0
# 3                  Steakhouse   0.0
# 4          Seafood Restaurant   0.0
# 5                    Sake Bar   0.0
# 6                    Pie Shop   0.0
# 7      Okonomiyaki Restaurant   0.0
# 8               Movie Theater   0.0
# 9          Mexican Restaurant   0.0
# 10        Japanese Restaurant   0.0
# 11          Indian Restaurant   0.0
# 12                     Bakery   0.0
# 13              Grocery Store   0.0
# 14          German Restaurant   0.0
# 15                  Gastropub   0.0
# 16                Coffee Shop   0.0
# 17                       Café   0.0
# 18                     Buffet   0.0
# 19       Brazilian Restaurant   0.0
# 20                   Beer Bar   0.0
# 21           Sushi Restaurant   0.0

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['city']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Popular Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Popular Venue'.format(ind+1))

# create a new dataframe
shinagawa_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
shinagawa_neighborhoods_venues_sorted['city'] = shinagawa_grouped['city']

for ind in np.arange(shinagawa_grouped.shape[0]):
    shinagawa_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(shinagawa_grouped.iloc[ind, :], num_top_venues)

shinagawa_neighborhoods_venues_sorted.head()
# Out:
#   city 1st Most Popular Venue 2nd Most Popular Venue  \
# 0   東京            Coffee Shop                 Bakery
# 1   港区                  Hotel               Aquarium
#
#       3rd Most Popular Venue     4th Most Popular Venue  \
# 0                   Aquarium  Japanese Curry Restaurant
# 1  Japanese Curry Restaurant                 Steakhouse
#
#   5th Most Popular Venue 6th Most Popular Venue 7th Most Popular Venue  \
# 0             Steakhouse     Seafood Restaurant               Sake Bar
# 1     Seafood Restaurant               Sake Bar               Pie Shop
#
#    8th Most Popular Venue  9th Most Popular Venue 10th Most Popular Venue
# 0                Pie Shop  Okonomiyaki Restaurant           Movie Theater
# 1  Okonomiyaki Restaurant           Movie Theater      Mexican Restaurant

# %%
# set number of clusters
kclusters = 2

shinagawa_grouped_clustering = shinagawa_grouped.drop('city', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(shinagawa_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1], dtype=int32)

# %%
# add clustering labels
shinagawa_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

shinagawa_merged = shinagawa_dataframe_filtered

# merge osaka_grouped with osaka_data to add latitude/longitude for each city
shinagawa_merged = shinagawa_merged.join(shinagawa_neighborhoods_venues_sorted.set_index('city'), on='city')

shinagawa_merged.head(5) # check the last columns!
# Out:
#                                                 name            categories  \
# 0                                           Barbacoa  Brazilian Restaurant
# 1                                      Rojiura (路地裏)              Sake Bar
# 2  Strings by InterContinental Tokyo (ストリングスホテル東京...                 Hotel
# 3                               Saza Coffee (サザコーヒー)           Coffee Shop
# 4                                        El Caliente    Mexican Restaurant
#
#      address          crossStreet        lat         lng  \
# 0  高輪4-10-18        ウィング高輪WEST 3F  35.628515  139.736955
# 1    港南2-2-4                  NaN  35.629259  139.742355
# 2   港南2-16-1  品川イーストワンタワー 26F-32F  35.627907  139.740726
# 3  高輪3-26-27           ecute品川 1F  35.628469  139.739426
# 4   港南2-18-1             アトレ品川 4F  35.629079  139.740651
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 35.6285145, 'lng'...       229   108-0074  JP
# 1  [{'label': 'display', 'lat': 35.62925904771133...       279   108-0075  JP
# 2  [{'label': 'display', 'lat': 35.6279075, 'lng'...       209   108-8282  JP
# 3  [{'label': 'display', 'lat': 35.62846913172101...       101   108-0074  JP
# 4  [{'label': 'display', 'lat': 35.629079, 'lng':...       129   108-0075  JP
#
#    ... 1st Most Popular Venue 2nd Most Popular Venue  \
# 0  ...            Coffee Shop                 Bakery
# 1  ...            Coffee Shop                 Bakery
# 2  ...                  Hotel               Aquarium
# 3  ...            Coffee Shop                 Bakery
# 4  ...            Coffee Shop                 Bakery
#
#       3rd Most Popular Venue     4th Most Popular Venue  \
# 0                   Aquarium  Japanese Curry Restaurant
# 1                   Aquarium  Japanese Curry Restaurant
# 2  Japanese Curry Restaurant                 Steakhouse
# 3                   Aquarium  Japanese Curry Restaurant
# 4                   Aquarium  Japanese Curry Restaurant
#
#   5th Most Popular Venue 6th Most Popular Venue  7th Most Popular Venue  \
# 0             Steakhouse     Seafood Restaurant                Sake Bar
# 1             Steakhouse     Seafood Restaurant                Sake Bar
# 2     Seafood Restaurant               Sake Bar                Pie Shop
# 3             Steakhouse     Seafood Restaurant                Sake Bar
# 4             Steakhouse     Seafood Restaurant                Sake Bar
#
#    8th Most Popular Venue  9th Most Popular Venue 10th Most Popular Venue
# 0                Pie Shop  Okonomiyaki Restaurant           Movie Theater
# 1                Pie Shop  Okonomiyaki Restaurant           Movie Theater
# 2  Okonomiyaki Restaurant           Movie Theater      Mexican Restaurant
# 3                Pie Shop  Okonomiyaki Restaurant           Movie Theater
# 4                Pie Shop  Okonomiyaki Restaurant           Movie Theater
#
# [5 rows x 27 columns]

# %%
# create map

import matplotlib.cm as cm
import matplotlib.colors as colors

shinagawa_map_clusters = folium.Map(shinagawa_location=[shinagawa_latitude, shinagawa_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(shinagawa_merged['lat'], shinagawa_merged['lng'], shinagawa_merged['city'], shinagawa_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(shinagawa_map_clusters)
       
shinagawa_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2966ad61be9c40a9ba9ea893f49a2d47%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2966ad61be9c40a9ba9ea893f49a2d47%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2966ad61be9c40a9ba9ea893f49a2d47%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2966ad61be9c40a9ba9ea893f49a2d47%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# #### Check on Sapporo Station, Sapporo, Japan  <a name="Check on Sapporo Station, Sapporo, Japan"></a>

# %%
## Get Coordinates of Sapporo Station, Sapporo, Japan

sapporo_address = 'Sapporo Station, Sapporo, Japan'

geolocator = Nominatim(user_agent="foursquare_agent")
sapporo_location = geolocator.geocode(sapporo_address)
sapporo_latitude = sapporo_location.latitude
sapporo_longitude = sapporo_location.longitude
print('The latitude and longitude for sapporo Station is:', sapporo_latitude, sapporo_longitude)
# Out:
# The latitude and longitude for sapporo Station is: 43.06860365 141.35079914476853

# %%
# Identify top 25 popular venue categories and subsequent top 25 venues around Umeda Station, Osaka Japan
sapporo_latitude = sapporo_location.latitude
sapporo_longitude= sapporo_location.longitude
radius = 2000
LIMIT = 25
sapporo_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, sapporo_latitude, sapporo_longitude, VERSION, radius, LIMIT)
sapporo_url

sapporo_results = requests.get(sapporo_url).json()
'There are {} around osaka Station, Osaka, Japan.'.format(len(sapporo_results['response']['groups'][0]['items']))

sapporo_items = sapporo_results['response']['groups'][0]['items']
sapporo_items[0]

sapporo_nearby_venues = json_normalize(sapporo_items) # flatten JSON

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter columns
sapporo_filtered_columns = ['venue.name', 'venue.categories'] + [col for col in sapporo_nearby_venues.columns if col.startswith('venue.location.')] + ['venue.id']
sapporo_dataframe_filtered = sapporo_nearby_venues.loc[:, sapporo_filtered_columns]

# filter the category for each row
sapporo_dataframe_filtered['venue.categories'] = sapporo_dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
sapporo_dataframe_filtered.columns = [col.split('.')[-1] for col in sapporo_dataframe_filtered.columns]

sapporo_dataframe_filtered.head(25)
# Out:
# <ipython-input-109-171c7a5d55de>:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   sapporo_nearby_venues = json_normalize(sapporo_items) # flatten JSON
#                                               name                 categories  \
# 0   JR Tower Observatory T38 (JRタワー展望室 タワー・スリーエイト)             Scenic Lookout
# 1                     Nemuro Hanamaru (回転寿司 根室花まる)           Sushi Restaurant
# 2                                 Rikyu (牛たん炭焼 利久)        Japanese Restaurant
# 3                                              味百仙                   Sake Bar
# 4                        Books Kinokuniya (紀伊國屋書店)                  Bookstore
# 5                Tokachi Butadon Ippin (十勝豚丼 いっぴん)         Donburi Restaurant
# 6                                            SKY J                        Bar
# 7                       Tonkatsu Tamafuji (とんかつ玉藤)        Tonkatsu Restaurant
# 8                Curry House Colombo (カリーハウス コロンボ)  Japanese Curry Restaurant
# 9                              175°DENO〜担担麺〜札幌駅北口店               Noodle House
# 10                         Rokkatei Café (六花亭 喫茶室)                       Café
# 11            Yodobashi Camera (ヨドバシカメラ マルチメディア札幌)          Electronics Store
# 12                 Yotsuba White Cosy (よつ葉ホワイトコージ)                       Café
# 13                                  Rokkatei (六花亭)                Pastry Shop
# 14           Sapporo Cinema Frontier (札幌シネマフロンティア)                  Multiplex
# 15                               YEBISU BAR 札幌アピア店                        Bar
# 16              Okushiba Shoten (スープカリー奥芝商店 駅前創成寺)  Japanese Curry Restaurant
# 17                                   KINOTOYA BAKE               Dessert Shop
# 18                    Shiki Hanamaru (町のすし家 四季花まる)           Sushi Restaurant
# 19     JR Tower Hotel Nikko Sapporo (JRタワーホテル日航札幌)                      Hotel
# 20                                    寿司と炉端焼 四季花まる           Sushi Restaurant
# 21               Sapporo Stellar Place (札幌ステラプレイス)              Shopping Mall
# 22                          Tonkatsu Wako (とんかつ和幸)        Tonkatsu Restaurant
# 23                           Sapporo Station (札幌駅)              Train Station
# 24                                          佐藤水産本店               Gourmet Shop
#
#          address       crossStreet        lat         lng  \
# 0     中央区北5条西2-5         JRタワー 38F  43.068179  141.352369
# 1     中央区北5条西2-5      札幌ステラプレイス 6F  43.067916  141.350547
# 2    北区北6条西2-1-7    札幌パセオ WEST B1F  43.068355  141.349618
# 3        北区北7条西4        宮澤興業ビル B1F  43.068965  141.348575
# 4     中央区北5条西5-7   sapporo55 1F-2F  43.067420  141.348364
# 5     中央区北5条西2-5      札幌ステラプレイス 6F  43.068070  141.351404
# 6     中央区北5条西2-5  JRタワーホテル日航札幌 35F  43.068130  141.352432
# 7     中央区北5条西2-1         札幌エスタ 10F  43.067482  141.352740
# 8       中央区北4条西4        札幌国際ビル B1F  43.066001  141.350587
# 9   中央区北7条西4-1-1        東カン札幌ビル 1F  43.069043  141.349416
# 10  中央区北4条西6-3-3            六花亭 2F  43.066019  141.346597
# 11  北区北6条西5-1-22               NaN  43.068503  141.347896
# 12     北区北6条西4丁目    札幌パセオ WEST B1F  43.067876  141.348718
# 13  中央区北4条西6-3-3               NaN  43.065972  141.346568
# 14    中央区北5条西2-5      札幌ステラプレイス 7F  43.067909  141.351159
# 15    中央区北5条西4丁目              APIA  43.066855  141.349275
# 16  中央区北4条西1-1-3        ホクレンビル B1F  43.066908  141.353786
# 17       北区北6条西3   JR札幌駅 サツエキ イート内  43.068455  141.351362
# 18   北区北6条西2-1-7     PASEOウエスト B1F  43.067878  141.348646
# 19    中央区北5条西2-5               NaN  43.068220  141.353365
# 20  北区北7条西1丁目2-6         NCO札幌 B1F  43.069575  141.353461
# 21    中央区北5条西2-5      JRタワー B1F-9F  43.067994  141.350935
# 22   北区北6条西4-3-1           パセオ B1F  43.068624  141.349721
# 23   北区北6条西4-1-1               NaN  43.068548  141.350741
# 24    中央区北4条西3丁目          交洋ビル1~2F  43.066627  141.351374
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.06817938448641...       136   060-8503
# 1   [{'label': 'display', 'lat': 43.067916, 'lng':...        79   060-0005
# 2   [{'label': 'display', 'lat': 43.06835507085756...        99   060-0806
# 3   [{'label': 'display', 'lat': 43.068965, 'lng':...       185   060-0807
# 4   [{'label': 'display', 'lat': 43.06742, 'lng': ...       237   060-0005
# 5   [{'label': 'display', 'lat': 43.06806988507564...        77   060-0005
# 6   [{'label': 'display', 'lat': 43.06812952775766...       142   060-0005
# 7   [{'label': 'display', 'lat': 43.067482, 'lng':...       201   060-0005
# 8   [{'label': 'display', 'lat': 43.06600088601527...       290   060-0003
# 9   [{'label': 'display', 'lat': 43.069043, 'lng':...       122   060-0007
# 10  [{'label': 'display', 'lat': 43.06601865425463...       446   060-0004
# 11  [{'label': 'display', 'lat': 43.06850321889605...       236   060-0806
# 12  [{'label': 'display', 'lat': 43.06787562137168...       187   060-0806
# 13  [{'label': 'display', 'lat': 43.06597205405861...       451   060-0004
# 14  [{'label': 'display', 'lat': 43.067909, 'lng':...        82   060-0005
# 15  [{'label': 'display', 'lat': 43.0668552812682,...       230   060-0005
# 16  [{'label': 'display', 'lat': 43.06690813409403...       307   060-0004
# 17  [{'label': 'display', 'lat': 43.06845530583924...        48   060-0806
# 18  [{'label': 'display', 'lat': 43.06787831934166...       192   060-0806
# 19  [{'label': 'display', 'lat': 43.06822048194448...       213   060-8788
# 20  [{'label': 'display', 'lat': 43.06957528734628...       241   001-0017
# 21  [{'label': 'display', 'lat': 43.06799426177751...        68   060-0005
# 22  [{'label': 'display', 'lat': 43.068624, 'lng':...        87   060-0806
# 23  [{'label': 'display', 'lat': 43.068548, 'lng':...         7   001-0006
# 24  [{'label': 'display', 'lat': 43.06662653556376...       225   060-0004
#
#     cc neighborhood city state country  \
# 0   JP          中央区  札幌市   北海道      日本
# 1   JP          NaN  札幌市   北海道      日本
# 2   JP          NaN  札幌市   北海道      日本
# 3   JP          NaN  札幌市   北海道      日本
# 4   JP          札幌市  札幌市   北海道      日本
# 5   JP          NaN  札幌市   北海道      日本
# 6   JP          NaN  札幌市   北海道      日本
# 7   JP          NaN  札幌市   北海道      日本
# 8   JP          中央区  札幌市   北海道      日本
# 9   JP          NaN  札幌市   北海道      日本
# 10  JP          NaN  札幌市   北海道      日本
# 11  JP           北区  札幌市   北海道      日本
# 12  JP          NaN  札幌市   北海道      日本
# 13  JP          NaN  札幌市   北海道      日本
# 14  JP          中央区  札幌市   北海道      日本
# 15  JP          NaN  札幌市   北海道      日本
# 16  JP          NaN  札幌市   北海道      日本
# 17  JP          NaN  札幌市   北海道      日本
# 18  JP           北区  札幌市   北海道      日本
# 19  JP          中央区  札幌市   北海道      日本
# 20  JP          NaN  札幌市   北海道      日本
# 21  JP          NaN  札幌市   北海道      日本
# 22  JP          NaN  札幌市   北海道      日本
# 23  JP          NaN  札幌市   北海道      日本
# 24  JP          NaN  札幌市   北海道      日本
#
#                                      formattedAddress  \
# 0    [中央区北5条西2-5 (JRタワー 38F), 札幌市, 北海道, 060-8503, 日本]
# 1   [中央区北5条西2-5 (札幌ステラプレイス 6F), 札幌市, 北海道, 060-0005...
# 2   [北区北6条西2-1-7 (札幌パセオ WEST B1F), 札幌市, 北海道, 060-0...
# 3      [北区北7条西4 (宮澤興業ビル B1F), 札幌市, 北海道, 060-0807, 日本]
# 4   [中央区北5条西5-7 (sapporo55 1F-2F), 札幌市, 北海道, 060-0...
# 5   [中央区北5条西2-5 (札幌ステラプレイス 6F), 札幌市, 北海道, 060-0005...
# 6   [中央区北5条西2-5 (JRタワーホテル日航札幌 35F), 札幌市, 北海道, 060-...
# 7    [中央区北5条西2-1 (札幌エスタ 10F), 札幌市, 北海道, 060-0005, 日本]
# 8     [中央区北4条西4 (札幌国際ビル B1F), 札幌市, 北海道, 060-0003, 日本]
# 9   [中央区北7条西4-1-1 (東カン札幌ビル 1F), 札幌市, 北海道, 060-0007...
# 10    [中央区北4条西6-3-3 (六花亭 2F), 札幌市, 北海道, 060-0004, 日本]
# 11             [北区北6条西5-1-22, 札幌市, 北海道, 060-0806, 日本]
# 12  [北区北6条西4丁目 (札幌パセオ WEST B1F), 札幌市, 北海道, 060-080...
# 13             [中央区北4条西6-3-3, 札幌市, 北海道, 060-0004, 日本]
# 14  [中央区北5条西2-5 (札幌ステラプレイス 7F), 札幌市, 北海道, 060-0005...
# 15        [中央区北5条西4丁目 (APIA), 札幌市, 北海道, 060-0005, 日本]
# 16  [中央区北4条西1-1-3 (ホクレンビル B1F), 札幌市, 北海道, 060-0004...
# 17  [北区北6条西3 (JR札幌駅 サツエキ イート内), 札幌市, 北海道, 060-0806...
# 18  [北区北6条西2-1-7 (PASEOウエスト B1F), 札幌市, 北海道, 060-08...
# 19               [中央区北5条西2-5, 札幌市, 北海道, 060-8788, 日本]
# 20  [北区北7条西1丁目2-6 (NCO札幌 B1F), 札幌市, 北海道, 001-0017,...
# 21  [中央区北5条西2-5 (JRタワー B1F-9F), 札幌市, 北海道, 060-0005...
# 22    [北区北6条西4-3-1 (パセオ B1F), 札幌市, 北海道, 060-0806, 日本]
# 23              [北区北6条西4-1-1, 札幌市, 北海道, 001-0006, 日本]
# 24    [中央区北4条西3丁目 (交洋ビル1~2F), 札幌市, 北海道, 060-0004, 日本]
#
#                           id
# 0   4ba4664df964a520db9a38e3
# 1   4b6d3cb6f964a520f16c2ce3
# 2   50ac7a73e4b02888e570ff02
# 3   4b975ea3f964a520370135e3
# 4   4b5726c5f964a520762828e3
# 5   5468286d498e87b190fbbb9c
# 6   4bca74b70687ef3b2c30dccc
# 7   4e2113331838712abe6e83e8
# 8   4b626b9df964a520ec462ae3
# 9   56383361cd102b4591fae138
# 10  5a7e4c58840fc24945b376cf
# 11  4b583455f964a520ec4d28e3
# 12  4baf2e9df964a5209cef3be3
# 13  5598b6d5498e978d4396fd1f
# 14  4b55d4fcf964a520f7f127e3
# 15  5530b252498e56b3c7431ccc
# 16  52777785498ed3c3cb1639d6
# 17  508a03a7e4b0e1fc29e1a24e
# 18  4e21268715207ed86eb59993
# 19  4bafa892f964a520bc143ce3
# 20  58febf890e5da81c73d79bb7
# 21  4c10ac71f1b6a593663d7c27
# 22  4ba746caf964a520348939e3
# 23  4b588558f964a520dd5b28e3
# 24  4b62b320f964a520804f2ae3

# %%
sapporo_venues_map = folium.Map(sapporo_location=[sapporo_latitude, sapporo_longitude], zoom_start=15) # generate map centred around sapporo Station


# add sapporo as a red circle mark
folium.CircleMarker(
    [osaka_latitude, osaka_longitude],
    radius=10,
    popup='sapporo Station',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(sapporo_venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(sapporo_dataframe_filtered.head(25).lat, sapporo_dataframe_filtered.lng, sapporo_dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(sapporo_venues_map)

# display map
sapporo_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_22a34c53e723454b896da77f8e819a5d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_22a34c53e723454b896da77f8e819a5d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_22a34c53e723454b896da77f8e819a5d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_22a34c53e723454b896da77f8e819a5d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
# one hot encoding
sapporo_onehot = pd.get_dummies(sapporo_dataframe_filtered[['categories']], prefix="", prefix_sep="")

# add categories column back to dataframe
sapporo_onehot['city'] = sapporo_dataframe_filtered['city'] 

# move categories column to the first column
sapporo_fixed_columns = [sapporo_onehot.columns[-1]] + list(sapporo_onehot.columns[:-1])
sapporo_onehot = sapporo_onehot[sapporo_fixed_columns]

sapporo_onehot.head()

sapporo_onehot.shape

sapporo_grouped = sapporo_onehot.groupby('city').mean().reset_index()
sapporo_grouped

sapporo_grouped.shape


num_top_venues = 25

for city in sapporo_grouped['city']:
    print("----"+city+"----")
    temp = sapporo_grouped[sapporo_grouped['city'] == city].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----札幌市----
#                         venue  freq
# 0            Sushi Restaurant  0.12
# 1                         Bar  0.08
# 2                        Café  0.08
# 3         Tonkatsu Restaurant  0.08
# 4   Japanese Curry Restaurant  0.08
# 5                Noodle House  0.04
# 6               Shopping Mall  0.04
# 7              Scenic Lookout  0.04
# 8                    Sake Bar  0.04
# 9                 Pastry Shop  0.04
# 10        Japanese Restaurant  0.04
# 11                  Multiplex  0.04
# 12                  Bookstore  0.04
# 13                      Hotel  0.04
# 14               Gourmet Shop  0.04
# 15          Electronics Store  0.04
# 16         Donburi Restaurant  0.04
# 17               Dessert Shop  0.04
# 18              Train Station  0.04

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['city']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Popular Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Popular Venue'.format(ind+1))

# create a new dataframe
sapporo_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
sapporo_neighborhoods_venues_sorted['city'] = sapporo_grouped['city']

for ind in np.arange(sapporo_grouped.shape[0]):
    sapporo_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sapporo_grouped.iloc[ind, :], num_top_venues)

sapporo_neighborhoods_venues_sorted.head()
# Out:
#   city 1st Most Popular Venue 2nd Most Popular Venue 3rd Most Popular Venue  \
# 0  札幌市       Sushi Restaurant                    Bar                   Café
#
#   4th Most Popular Venue     5th Most Popular Venue 6th Most Popular Venue  \
# 0    Tonkatsu Restaurant  Japanese Curry Restaurant           Noodle House
#
#   7th Most Popular Venue 8th Most Popular Venue 9th Most Popular Venue  \
# 0          Shopping Mall         Scenic Lookout               Sake Bar
#
#   10th Most Popular Venue
# 0             Pastry Shop

# %%
# set number of clusters
kclusters = 1

sapporo_grouped_clustering = sapporo_grouped.drop('city', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sapporo_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0], dtype=int32)

# %%
# add clustering labels
sapporo_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

sapporo_merged = sapporo_dataframe_filtered

# merge osaka_grouped with osaka_data to add latitude/longitude for each city
sapporo_merged = sapporo_merged.join(sapporo_neighborhoods_venues_sorted.set_index('city'), on='city')

sapporo_merged.head(5) # check the last columns!
# Out:
#                                              name           categories  \
# 0  JR Tower Observatory T38 (JRタワー展望室 タワー・スリーエイト)       Scenic Lookout
# 1                    Nemuro Hanamaru (回転寿司 根室花まる)     Sushi Restaurant
# 2                                Rikyu (牛たん炭焼 利久)  Japanese Restaurant
# 3                                             味百仙             Sake Bar
# 4                       Books Kinokuniya (紀伊國屋書店)            Bookstore
#
#        address      crossStreet        lat         lng  \
# 0   中央区北5条西2-5        JRタワー 38F  43.068179  141.352369
# 1   中央区北5条西2-5     札幌ステラプレイス 6F  43.067916  141.350547
# 2  北区北6条西2-1-7   札幌パセオ WEST B1F  43.068355  141.349618
# 3      北区北7条西4       宮澤興業ビル B1F  43.068965  141.348575
# 4   中央区北5条西5-7  sapporo55 1F-2F  43.067420  141.348364
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.06817938448641...       136   060-8503  JP
# 1  [{'label': 'display', 'lat': 43.067916, 'lng':...        79   060-0005  JP
# 2  [{'label': 'display', 'lat': 43.06835507085756...        99   060-0806  JP
# 3  [{'label': 'display', 'lat': 43.068965, 'lng':...       185   060-0807  JP
# 4  [{'label': 'display', 'lat': 43.06742, 'lng': ...       237   060-0005  JP
#
#    ... 1st Most Popular Venue 2nd Most Popular Venue 3rd Most Popular Venue  \
# 0  ...       Sushi Restaurant                    Bar                   Café
# 1  ...       Sushi Restaurant                    Bar                   Café
# 2  ...       Sushi Restaurant                    Bar                   Café
# 3  ...       Sushi Restaurant                    Bar                   Café
# 4  ...       Sushi Restaurant                    Bar                   Café
#
#   4th Most Popular Venue     5th Most Popular Venue 6th Most Popular Venue  \
# 0    Tonkatsu Restaurant  Japanese Curry Restaurant           Noodle House
# 1    Tonkatsu Restaurant  Japanese Curry Restaurant           Noodle House
# 2    Tonkatsu Restaurant  Japanese Curry Restaurant           Noodle House
# 3    Tonkatsu Restaurant  Japanese Curry Restaurant           Noodle House
# 4    Tonkatsu Restaurant  Japanese Curry Restaurant           Noodle House
#
#    7th Most Popular Venue 8th Most Popular Venue 9th Most Popular Venue  \
# 0           Shopping Mall         Scenic Lookout               Sake Bar
# 1           Shopping Mall         Scenic Lookout               Sake Bar
# 2           Shopping Mall         Scenic Lookout               Sake Bar
# 3           Shopping Mall         Scenic Lookout               Sake Bar
# 4           Shopping Mall         Scenic Lookout               Sake Bar
#
#   10th Most Popular Venue
# 0             Pastry Shop
# 1             Pastry Shop
# 2             Pastry Shop
# 3             Pastry Shop
# 4             Pastry Shop
#
# [5 rows x 27 columns]

# %%
# create map

import matplotlib.cm as cm
import matplotlib.colors as colors

sapporo_map_clusters = folium.Map(sapporo_location=[sapporo_latitude, sapporo_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sapporo_merged['lat'], sapporo_merged['lng'], sapporo_merged['city'], sapporo_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(sapporo_map_clusters)
       
sapporo_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_40efb06194cc4701b6d7f2000f9da223%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_40efb06194cc4701b6d7f2000f9da223%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_40efb06194cc4701b6d7f2000f9da223%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_40efb06194cc4701b6d7f2000f9da223%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>
